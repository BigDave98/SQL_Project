# %% [markdown]
# # Projeto Final curos SQL sobre analise exploratoria de dados
#
# This notebook represents the final project of the course SQL for data analisis from EBAC.

# %% [markdown]
# # About DataSet
# This dataset was derived from https://www.cardekho.com/. The dataset consists specifications list as we all rating only for new cars.
#
# # About the data
# The data represents 16 features on a total of 203 car choices avaliable in india
# * Car Name: Name of the car
# * Reviews count: Number of reviews given to the specific car on the website
# * Fuel Type: Type of Fuel car uses. Possible values are Petrol, Diesel and Electric
# * Engine Displacement (cc): Engine displacement is the measure of the cylinder volume swept by all of the pistons of a piston engine, excluding the combustion chambers. Unit is (cc)
# * No. of cylinder: Number of cylinders contained by the car. 0 in case of electric vehicles
# * Seating Capacity: Number of people that can fit in the car
# * Transmission Type: Possible values range from Manual, Automatic and Electric
# * Fuel Tank Capacity: Maximum capacity of car's fuel tank. 0 in case of electric vehicle
# * Body Type: Body shape of the car
# * Rating: Rating provided to the car on the website. In the range of 0 to 5
# * Starting Price: Starting price of the car in Rs
# * Max Torque (Nm): Maximum torque that can be provided by the car
# * Max Torque (RPM): RPM at which maximum torque can be achieved
# * Max Power (BHP): Maximum horsepower of the car
# * Max Power (RPM): RPM at which maximum horsepower can be achieved

# %% [markdown]
# # DataSet exploration:
# The first thing to do is understand what we have in the DataSet.
#
# * **How much lines we have on the DataSet?**
#
# **Query**: SELECT count(*) FROM cars
#
#
# ![image.png](attachment:2a8b1f15-4f66-432a-802e-3c8cbe2dfe92.png)
#
#
# * **Wich kind of data we have?**
#
# **Query**: DESCRIBE cars
#
# ![image.png](attachment:320e1d28-f619-409c-9afc-382702f8776f.png)
#
#
# * **Wich kinds of Fuel, Transmition and body we have?**
#
# **Query**: SELECT DISTINCT body_type FROM cars
#
# ![image.png](attachment:03a6ccd8-1097-4dd4-9f28-d15d29c10dee.png)
#
# **Query**: SELECT DISTINCT fuel_type FROM cars
#
# ![image.png](attachment:ccf3fec9-f165-4edd-a529-8cfe80c7a591.png)
#
# **Query**: SELECT DISTINCT transmission_type FROM cars
#
# ![image.png](attachment:fe63b70c-2f77-428b-801f-5d88842d1033.png)
#
#
#
# # Data Analisys
#
# * **First we can find witch type of fuel and transmition has the best ratting**
#
# **Query**:
#
# ![image.png](attachment:d3730345-91bc-455a-9e33-a02c9a171003.png)
#
#
# ![image.png](attachment:aa78ce28-ed5d-4cbf-8fde-32073ef17d90.png)
#
# The types of transmitions that requires less effort are best the rated.
#
# ![image.png](attachment:9f6beef7-9c64-4476-bd6f-148abc512240.png)
# ![image.png](attachment:948518e9-094d-4062-b47b-1f4da975ae99.png)
#
# As we can see eletric engines are the best rated, maybe because of the power of this kind of engine and low cost of maintence.
#
# * **Then we can do a exploratory analysis to find the best rated kind of car with some parameters that can help us to understand the results**
#
# **Query**:
#
# ![image.png](attachment:ce69e8e0-14ec-4a86-a9c4-9f7339a56822.png)
#
#
# ![image.png](attachment:814a7c00-52df-455f-a2f7-348d0005a820.png)![download.png]
#
# As we can see the Coupe is the car with the best average of rate, this same kind is the one that has less seats, a considerable tank capacity and is the second type of car with most cylinders when compared to the others.
#
# In the other hand we have the hatchback with the lowest rated type of car. It is the kind of car with the less number of cylinders and the smallest tank.
#
# This analysis do not give us a precise answer of why is these type of cars have been rated like that
# .
# * **Now we can compare the prices of each type**
#
# **Query**:
#
# ![image.png](attachment:564aaea5-7b0c-4488-8c85-a82ca9d4ae0e.png)
#
# ![image.png](attachment:45a717f2-4baf-4015-b764-4dd5a6820bfe.png)
#
# As we can see the Coupe cars are the second most expensive cars in this DataSet. This can make us believe that these have a good rating because they are built with better quality and more expensive materials.
#
# While the hachback type is the oposite of the coupe, with the lowest prices, and probably a worst manufacturing quality.
#
#
# * **Comparing the power of each type**
#
# **Query**:
#
# ![image.png](attachment:1feac3f3-2c8a-4263-95c2-645c630b36da.png)
#
#
# ![image.png](attachment:63af9a8f-32ec-4e33-a618-799c1e2f2a89.png)
#
# As we can see the coupe is the type of car with most engine power, this is a good indicator of driving quality.
# Again the hachback is the one that represnts the lowest results of all types in this DataSet, indicating a bad user driving experience.

# %% [markdown]
# # Conclusion
#
# * It's noticiable that the price of the car probably influences the quality of the same, giving a better experience to the user.
#
# * As we can see the engine size and the power of the car improves the driving experience making the car better.
#
# * The kind of fuel and transmition influences the rating of the car.
